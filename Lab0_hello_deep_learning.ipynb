# %% [markdown]
# <a href="https://colab.research.google.com/github/M90X-2/IT480-FA26/blob/main/Lab0_hello_deep_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy, pandas, matplotlib, sklearn, tensorflow
print("Environment OK — all libraries loaded")
print("TensorFlow version:", tensorflow.__version__)
# Out:
# Environment OK — all libraries loaded
# TensorFlow version: 2.20.0

# %% [markdown]
# #Maximilian Vogel
